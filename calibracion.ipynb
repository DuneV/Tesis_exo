# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
plt.style.use('classic')

# %%
data = pd.read_excel('calibración.xlsx')
data.head(3)
# Out:
#    Aceleracion_X0  Aceleracion_Y0  Aceleracion_Z0  Gyro_X0  Gyro_Y0  Gyro_Z0  \
# 0            0.50           -0.38            9.07     0.05     0.02    -0.09
# 1            0.49           -0.38            9.07     0.05     0.02    -0.09
# 2            0.49           -0.38            9.05     0.05     0.02    -0.09
#
#    Temperatura1  Aceleracion_X1  Aceleracion_Y1  Aceleracion_Z1  Gyro_X1  \
# 0         24.59            0.28            0.11            7.38     0.03
# 1         24.60            0.28            0.12            7.38     0.03
# 2         24.59            0.29            0.13            7.39     0.03
#
#    Gyro_Y1  Gyro_Z1  Temperatura1.1
# 0     0.01    -0.01           25.95
# 1     0.01    -0.01           25.96
# 2     0.01    -0.02           25.97

# %%
# Plotear las columnas usando matplotlib
plt.plot(data['Aceleracion_X0'], label='$Aceleracion_{X0}$')
plt.plot(data['Aceleracion_Y0'], label='$Aceleracion_{Y0}$')
plt.plot(data['Aceleracion_X1'], label='$Aceleracion_{X1}$')
plt.plot(data['Aceleracion_Y1'], label='$Aceleracion_{Y1}$')
# Agregar una línea de referencia horizontal en y=3
plt.axhline(y=0, color='r', linestyle='--', label='$Referencia$')

# Añadir etiquetas y leyenda
plt.title('$Aceleraciones\; vs \;muestra$')
plt.xlabel('$Muestra No.$')
plt.grid()
plt.ylabel(r'$m/s^2$')
plt.legend()

# Mostrar el gráfico
plt.show()

# %%
# Plotear las columnas usando matplotlib
plt.plot(data['Aceleracion_Z0'], label='$Aceleracion_{Z0}$')
plt.plot(data['Aceleracion_Z1'], label='$Aceleracion_{Z1}$')
# Agregar una línea de referencia horizontal en y=3
plt.axhline(y=9.8, color='r', linestyle='--', label='$gravedad$')

# Añadir etiquetas y leyenda
plt.title('Aceleraciones vs muestra')
plt.xlabel('Muestra No.')
plt.grid()
plt.ylabel(r'$m/s^2$')
plt.legend()

# Mostrar el gráfico
plt.show()

# %%
# Plotear las columnas usando matplotlib
plt.plot(data['Gyro_X0'], label='$Gyro_{X0}$')
plt.plot(data['Gyro_Y0'], label='$Gyro_{Y0}$')
plt.plot(data['Gyro_Z0'], label='$Gyro_{Z0}$')
plt.plot(data['Gyro_X1'], label='$Gyro_{X1}$')
plt.plot(data['Gyro_Y1'], label='$Gyro_{Y1}$')
plt.plot(data['Gyro_Z1'], label='$Gyro_{Z1}$')

# Agregar una línea de referencia horizontal en y=3
plt.axhline(y=0, color='r', linestyle='--', label='$Referencia$')

# Añadir etiquetas y leyenda
plt.title('$Aceleraciones\; vs \;muestra$')
plt.xlabel('$Muestra No.$')
plt.grid()
plt.ylabel(r'$m/s^2$')
plt.legend()

# Mostrar el gráfico
plt.show()
